# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\LigaDB.csv')
df1= pd.read_csv(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\RMA.csv')
df2= pd.read_csv(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\Sevilla.csv')
df3= pd.read_csv(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\Betis.csv')
df4= pd.read_csv(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\Atleti.csv')
df5= pd.read_csv(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\Villa.csv')
df6= pd.read_csv(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\Barca.csv')

# %%
df1.head()
# Out:
#          Date           Time        Round  Day Venue Result  GF  GA  \
# 0  2021-08-14  22:00 (01:30)  Matchweek 1  Sat  Away      W   4   1
# 1  2021-08-22  22:00 (01:30)  Matchweek 2  Sun  Away      D   3   3
# 2  2021-08-28  22:00 (01:30)  Matchweek 3  Sat  Away      W   1   0
# 3  2021-09-12  21:00 (00:30)  Matchweek 4  Sun  Home      W   5   2
# 4  2021-09-19  21:00 (00:30)  Matchweek 5  Sun  Away      W   2   1
#
#      Opponent   xG  xGA  Poss  Attendance        Captain Formation  \
# 0      Alavés  1.8  1.7    58        3968  Karim Benzema  4-3-2003
# 1     Levante  1.2  1.9    62        9838  Karim Benzema  4-3-2003
# 2       Betis  1.1  0.8    49       22590  Karim Benzema  4-3-2003
# 3  Celta Vigo  3.4  1.8    60       19874  Karim Benzema  4-4-2002
# 4    Valencia  1.1  0.8    61       26689  Karim Benzema   4-4-1-1
#
#                Referee  Match Report  Notes
# 0           César Soto  Match Report    NaN
# 1     Guillermo Cuadra  Match Report    NaN
# ...

# %%
xG=list(df['xG'])
xGA=list(df['xGA'])
xG1=list(df1['xG'])
venue1=list(df1['Venue'])
xGA1=list(df1['xGA'])
xG2=list(df2['xG'])
venue2=list(df2['Venue'])
venue3=list(df3['Venue'])
venue4=list(df4['Venue'])
venue5=list(df5['Venue'])
venue6=list(df6['Venue'])
xGA2=list(df2['xGA'])
xG3=list(df3['xG'])
xGA3=list(df3['xGA'])
xG4=list(df4['xG'])
xGA4=list(df4['xGA'])
xG5=list(df5['xG'])
xGA5=list(df5['xGA'])
xG6=list(df6['xG'])
xGA6=list(df6['xGA'])

# %%
df.head()
# Out:
#     Wk  Day        Date           Time      Home   xG Score  xGA         Away  \
# 0  1.0  Fri  2021-08-13  21:00 (00:30)  Valencia  1.3   1–0  1.2       Getafe
# 1  1.0  Sat  2021-08-14  19:30 (23:00)  Mallorca  0.4   1–1  0.9        Betis
# 2  1.0  Sat  2021-08-14  19:30 (23:00)     Cádiz  0.4   1–1  1.0      Levante
# 3  1.0  Sat  2021-08-14  22:00 (01:30)   Osasuna  0.8   0–0  0.7     Espanyol
# 4  1.0  Sat  2021-08-14  22:00 (01:30)    Alavés  1.7   1–4  1.8  Real Madrid
#
#    Attendance                     Venue                   Referee  \
# 0      9868.0       Estadio de Mestalla                 Jesús Gil
# 1      6279.0          Iberostar Estadi       Antonio Matéu Lahoz
# 2      6941.0  Estadio Nuevo Mirandilla            Santiago Jaime
# 3      6715.0          Estadio El Sadar  Miguel Ángel Ortiz Arias
# 4      3968.0   Estadio de Mendizorroza                César Soto
#
#    Match Report Notes
# 0  Match Report   NaN
# 1  Match Report   NaN
# 2  Match Report   NaN
# ...

# %%
home=list(df['Home'])
away=list(df['Away'])

# %%
teams=list(df['Home'])

# %%
teams=list(set(teams))

# %%
plt.figure(figsize=(7.6,5.5)) 
#plt.plot(x, x, linestyle='dashed')
ax=plt.axes()
ax.plot([0, 1], [0, 1], transform=ax.transAxes, linestyle='dashed',color='black')
arrowprops = dict(arrowstyle="->", connectionstyle="arc3,rad=+0.6",lw=2)
arrowprops1 = dict(arrowstyle="->", connectionstyle="arc3,rad=-0.3",lw=2)

plt.text(
    -.1, 5.9, f"1", size=53,
    color="#000000",
    fontproperties=font_number.prop,
    ha="left"
)   

TITLE1='Real Madrid'
TITLE2='25 Matches | 57 Points'
TITLE3='44 xG | 25.2 xGA'
plt.text(
    5.6,5.9, f"\n{TITLE1}\n{TITLE2}\n{TITLE3}", size=15,
    color="darkviolet",
    fontproperties=font_fig.prop,
    ha="right"
)   




for i in range(len(teams)):
    for j in range(len(xG)):   
            if(teams[i] in ['Real Madrid']):
                if(home[j] in ['Real Madrid']):
                     plt.scatter(
                     x=xGA[j],
                     y=xG[j],
                     s=200,
                     facecolor='floralwhite',
                     edgecolor='black',
                     linewidth=2,
                     alpha=1
                 )
            elif(away[j] in ['Real Madrid']):
                   plt.scatter(
                   x=xG[j],
                   y=xGA[j],
                   s=200,
                   facecolor='floralwhite',
                   edgecolor='black',
                   linewidth=2,
                   alpha=1)
                    
            else:        
                if(home[j]==teams[i]):            
                    plt.scatter(
                    x=xGA[j],
                    y=xG[j],
                    s=100,
                    c='black',
                    alpha=.08
                   )
                if(away[j]==teams[i]):
                    plt.scatter(
                    x=xG[j],
                    y=xGA[j],
                    s=100,
                    c='black',
                    alpha=.08
                )
             


            
for i in range(len(xG)):
    if(home[i] in ['Real Madrid']and away[i]in ['Elche']):
         plt.annotate('Highest xG difference\nStill a draw', 
         (xGA[i], xG[i]),(xGA[i]+3,xG[i]+1),
         arrowprops=arrowprops,fontproperties=font_quad.prop,ha='center',
         size = 25)
    if(home[i] in ['Real Madrid']and away[i]in ['Getafe'] or away[i] in ['Real Madrid']and home[i]in ['Getafe']):
         plt.annotate('Lowest xG created', 
         (xG[i], xGA[i]),(xG[i]+3,xGA[i]),
         arrowprops=arrowprops1,fontproperties=font_quad.prop,ha='center',
         size = 25)    
     
            
    

plt.grid()            
plt.xlabel("xG Conceded",fontsize=20,fontproperties=font_normal.prop)
plt.ylabel("\nxG Created",fontsize=20,fontproperties=font_normal.prop)            
plt.yticks(fontsize=25,fontproperties=font_normal.prop)
plt.xticks(fontsize=25,fontproperties=font_normal.prop)
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(7.6,5.5)) 
#plt.plot(x, x, linestyle='dashed')
ax=plt.axes()
ax.plot([0, 1], [0, 1], transform=ax.transAxes, linestyle='dashed',color='black')
arrowprops = dict(arrowstyle="->", connectionstyle="arc3,rad=+0.6",lw=2)
arrowprops1 = dict(arrowstyle="->", connectionstyle="arc3,rad=-0.3",lw=2)

plt.text(
    -.1, 5.9, f"2", size=53,
    color="#000000",
    fontproperties=font_number.prop,
    ha="left"
)   

TITLE1='Sevilla'
TITLE2='24 Matches | 50 Points'
TITLE3='27.6 xG | 21.3 xGA'
plt.text(
    5.6,5.9, f"\n{TITLE1}\n{TITLE2}\n{TITLE3}", size=15,
    color="#EE4000",
    fontproperties=font_fig.prop,
    ha="right"
)   




for i in range(len(teams)):
    for j in range(len(xG)):   
            if(teams[i] in ['Sevilla']):
                if(home[j] in ['Sevilla']):
                     plt.scatter(
                     x=xGA[j],
                     y=xG[j],
                     s=200,
                     facecolor='#EE4000',
                     edgecolor='black',
                     linewidth=2,
                     alpha=1
                 )
            elif(away[j] in ['Sevilla']):
                   plt.scatter(
                   x=xG[j],
                   y=xGA[j],
                   s=200,
                   facecolor='#EE4000',
                   edgecolor='black',
                   linewidth=2,
                   alpha=1)
                    
            else:        
                if(home[j]==teams[i]):            
                    plt.scatter(
                    x=xGA[j],
                    y=xG[j],
                    s=100,
                    c='black',
                    alpha=.08
                   )
                if(away[j]==teams[i]):
                    plt.scatter(
                    x=xG[j],
                    y=xGA[j],
                    s=100,
                    c='black',
                    alpha=.08
                )
             


            
plt.annotate('Only 2 games where more\nthan 2xG created', 
       (0.2,3.5),(3,4),
       arrowprops=arrowprops,fontproperties=font_quad.prop,ha='center',
       size = 25)

plt.annotate('Riding their luck.\nLost only one game where\nopponents had more xG.\n 1-2 vs RMA', (1.5,.5),(4,1.6),
        arrowprops=arrowprops1,fontproperties=font_quad.prop,ha='center',
        size = 20)    
     
            
    

plt.grid()            
plt.xlabel("xG Conceded",fontsize=20,fontproperties=font_normal.prop)
plt.ylabel("\nxG Created",fontsize=20,fontproperties=font_normal.prop)            
plt.yticks(fontsize=25,fontproperties=font_normal.prop)
plt.xticks(fontsize=25,fontproperties=font_normal.prop)
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(7.6,5.5)) 
#plt.plot(x, x, linestyle='dashed')
ax=plt.axes()
ax.plot([0, 1], [0, 1], transform=ax.transAxes, linestyle='dashed',color='black')
arrowprops = dict(arrowstyle="->", connectionstyle="arc3,rad=+0.6",lw=2)
arrowprops1 = dict(arrowstyle="->", connectionstyle="arc3,rad=-0.3",lw=2)

plt.text(
    -.1, 5.9, f"3", size=53,
    color="#000000",
    fontproperties=font_number.prop,
    ha="left"
)   

TITLE1='Real Betis'
TITLE2='24 Matches | 43 Points'
TITLE3='37.3 xG | 30.3 xGA'
plt.text(
    5.6,5.9, f"\n{TITLE1}\n{TITLE2}\n{TITLE3}", size=15,
    color="#43CD80",
    fontproperties=font_fig.prop,
    ha="right"
)   




for i in range(len(teams)):
    for j in range(len(xG)):   
            if(teams[i] in ['Betis']):
                if(home[j] in ['Betis']):
                     plt.scatter(
                     x=xGA[j],
                     y=xG[j],
                     s=200,
                     facecolor='#43CD80',
                     edgecolor='black',
                     linewidth=2,
                     alpha=1
                 )
            elif(away[j] in ['Betis']):
                   plt.scatter(
                   x=xG[j],
                   y=xGA[j],
                   s=200,
                   facecolor='#43CD80',
                   edgecolor='black',
                   linewidth=2,
                   alpha=1)
                    
            else:        
                if(home[j]==teams[i]):            
                    plt.scatter(
                    x=xGA[j],
                    y=xG[j],
                    s=100,
                    c='black',
                    alpha=.08
                   )
                if(away[j]==teams[i]):
                    plt.scatter(
                    x=xG[j],
                    y=xGA[j],
                    s=100,
                    c='black',
                    alpha=.08
                )
             


            
#plt.annotate('Only 2 games where more\nthan 2xG created', 
#       (0.2,3.5),(3,4),
#       arrowprops=arrowprops,fontproperties=font_quad.prop,ha='center',
#       size = 25)

plt.annotate('Actual score different from xG\nscore only twice.\n2 (2.1)-3 (1.2) vs Athletic\n2 (2.1)-2 (1.2) vs Espanyol', (1.2,2.1),(3,4),
        arrowprops=arrowprops1,fontproperties=font_quad.prop,ha='center',
       size = 20)    
     
            
    

plt.grid()            
plt.xlabel("xG Conceded",fontsize=20,fontproperties=font_normal.prop)
plt.ylabel("\nxG Created",fontsize=20,fontproperties=font_normal.prop)            
plt.yticks(fontsize=25,fontproperties=font_normal.prop)
plt.xticks(fontsize=25,fontproperties=font_normal.prop)
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(7.6,5.5)) 
#plt.plot(x, x, linestyle='dashed')
ax=plt.axes()
ax.plot([0, 1], [0, 1], transform=ax.transAxes, linestyle='dashed',color='black')
arrowprops = dict(arrowstyle="->", connectionstyle="arc3,rad=+0.6",lw=2)
arrowprops1 = dict(arrowstyle="->", connectionstyle="arc3,rad=-0.3",lw=2)

plt.text(
    -.1, 5.9, f"4", size=53,
    color="#000000",
    fontproperties=font_number.prop,
    ha="left"
)   

TITLE1='Atlético Madrid'
TITLE2='25 Matches | 42 Points'
TITLE3='34.9xG | 21.6xGA'
plt.text(
    5.6,5.9, f"\n{TITLE1}\n{TITLE2}\n{TITLE3}", size=15,
    color="#EE0000",
    fontproperties=font_fig.prop,
    ha="right"
)   




for i in range(len(teams)):
    for j in range(len(xG)):   
            if(teams[i] in ['Atlético Madrid']):
                if(home[j] in ['Atlético Madrid']):
                     plt.scatter(
                     x=xGA[j],
                     y=xG[j],
                     s=200,
                     facecolor='#EE0000',
                     edgecolor='black',
                     linewidth=2,
                     alpha=1
                 )
            elif(away[j] in ['Atlético Madrid']):
                   plt.scatter(
                   x=xG[j],
                   y=xGA[j],
                   s=200,
                   facecolor='#EE0000',
                   edgecolor='black',
                   linewidth=2,
                   alpha=1)
                    
            else:        
                if(home[j]==teams[i]):            
                    plt.scatter(
                    x=xGA[j],
                    y=xG[j],
                    s=100,
                    c='black',
                    alpha=.08
                   )
                if(away[j]==teams[i]):
                    plt.scatter(
                    x=xG[j],
                    y=xGA[j],
                    s=100,
                    c='black',
                    alpha=.08
                )
             


            
plt.annotate('Conceded 14 goals from a combined\n4.4xG in 6 games', 
       (0.7,0.6),(1.5,4),
       arrowprops=arrowprops,fontproperties=font_quad.prop,
       size = 20)

plt.annotate('Only 3 games where\nxG is less than xGA.\n100% win record in these.', (2,1),(2.5,1.5),
        arrowprops=arrowprops1,fontproperties=font_quad.prop,
      size = 20)    
     
            
    

plt.grid()            
plt.xlabel("xG Conceded",fontsize=20,fontproperties=font_normal.prop)
plt.ylabel("\nxG Created",fontsize=20,fontproperties=font_normal.prop)            
plt.yticks(fontsize=25,fontproperties=font_normal.prop)
plt.xticks(fontsize=25,fontproperties=font_normal.prop)
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(7.6,5.5)) 
#plt.plot(x, x, linestyle='dashed')
ax=plt.axes()
ax.plot([0, 1], [0, 1], transform=ax.transAxes, linestyle='dashed',color='black')
arrowprops = dict(arrowstyle="->", connectionstyle="arc3,rad=+0.6",lw=2)
arrowprops1 = dict(arrowstyle="->", connectionstyle="arc3,rad=-0.3",lw=2)

plt.text(
    -.1, 5.9, f"5", size=53,
    color="#000000",
    fontproperties=font_number.prop,
    ha="left"
)   

TITLE1='Villarreal'
TITLE2='25 Matches | 39 Points'
TITLE3='43.4 xG | 29.3 xGA'
plt.text(
    5.6,5.9, f"\n{TITLE1}\n{TITLE2}\n{TITLE3}", size=15,
    color="#8B8B00",
    fontproperties=font_fig.prop,
    ha="right"
)   




for i in range(len(teams)):
    for j in range(len(xG)):   
            if(teams[i] in ['Villarreal']):
                if(home[j] in ['Villarreal']):
                     plt.scatter(
                     x=xGA[j],
                     y=xG[j],
                     s=200,
                     facecolor='#FFFF00',
                     edgecolor='black',
                     linewidth=2,
                     alpha=1
                 )
            elif(away[j] in ['Villarreal']):
                   plt.scatter(
                   x=xG[j],
                   y=xGA[j],
                   s=200,
                   facecolor='#FFFF00',
                   edgecolor='black',
                   linewidth=2,
                   alpha=1)
                    
            if(home[j]==teams[i]):            
                    plt.scatter(
                    x=xGA[j],
                    y=xG[j],
                    s=100,
                    c='black',
                    alpha=.08
                   )
            if(away[j]==teams[i]):
                    plt.scatter(
                    x=xG[j],
                    y=xGA[j],
                    s=100,
                    c='black',
                    alpha=.08
                )
             


            
plt.annotate('Highest xG created by an team in a game\n4-1 vs Granada. Arnaut Groneveld hat-trick!', 
       (2.8,5.4),(1,4),
       arrowprops=arrowprops,fontproperties=font_quad.prop,
       size = 20)

#plt.annotate('Only 3 games where\nxG is less than xGA.\n100% win record in these.', (2,1),(2.5,1.5),
#        arrowprops=arrowprops1,fontproperties=font_quad.prop,
#      size = 20)    
     
            
    

plt.grid()            
plt.xlabel("xG Conceded",fontsize=20,fontproperties=font_normal.prop)
plt.ylabel("\nxG Created",fontsize=20,fontproperties=font_normal.prop)            
plt.yticks(fontsize=25,fontproperties=font_normal.prop)
plt.xticks(fontsize=25,fontproperties=font_normal.prop)
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(7.6,5.5)) 
#plt.plot(x, x, linestyle='dashed')
ax=plt.axes()
ax.plot([0, 1], [0, 1], transform=ax.transAxes, linestyle='dashed',color='black')
arrowprops = dict(arrowstyle="->", connectionstyle="arc3,rad=-1.4",lw=2)
arrowprops1 = dict(arrowstyle="->", connectionstyle="arc3,rad=-0.3",lw=2)

plt.text(
    -.1, 5.9, f"6", size=53,
    color="#000000",
    fontproperties=font_number.prop,
    ha="left"
)   

TITLE1='Barcelona'
TITLE2='23 Matches | 39 Points'
TITLE3='35.7 xG | 21.7 xGA'
plt.text(
    5.6,5.9, f"\n{TITLE1}\n{TITLE2}\n{TITLE3}", size=15,
    color="#191970",
    fontproperties=font_fig.prop,
    ha="right"
)   




for i in range(len(teams)):
    for j in range(len(xG)):   
            if(teams[i] in ['Barcelona']):
                if(home[j] in ['Barcelona']):
                     plt.scatter(
                     x=xGA[j],
                     y=xG[j],
                     s=200,
                     facecolor='#191970',
                     edgecolor='black',
                     linewidth=3,
                     alpha=1
                 )
            elif(away[j] in ['Barcelona']):
                   plt.scatter(
                   x=xG[j],
                   y=xGA[j],
                   s=200,
                   facecolor='#191970',
                   edgecolor='black',
                   linewidth=3,
                   alpha=1)
                    
            if(home[j]==teams[i]):            
                    plt.scatter(
                    x=xGA[j],
                    y=xG[j],
                    s=100,
                    c='black',
                    alpha=.08
                   )
            if(away[j]==teams[i]):
                    plt.scatter(
                    x=xG[j],
                    y=xGA[j],
                    s=100,
                    c='black',
                    alpha=.08
                )
             


            
plt.text(1.1,4,'Barcelona have lost 7/16 games where they\nhad xG than their opponents ', 
        size = 20,fontproperties=font_quad.prop)

plt.annotate('7', (.9,1),(.6,4),
       arrowprops=arrowprops,fontproperties=font_italic.prop,
      size = 50)    
     
            
    

plt.grid()            
plt.xlabel("xG Conceded",fontsize=20,fontproperties=font_normal.prop)
plt.ylabel("\nxG Created",fontsize=20,fontproperties=font_normal.prop)            
plt.yticks(fontsize=25,fontproperties=font_normal.prop)
plt.xticks(fontsize=25,fontproperties=font_normal.prop)
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
from mplsoccer import FontManager

font_normal = FontManager(("https://github.com/google/fonts/blob/main/apache/arimo/Arimo%5Bwght%5D.ttf?raw=true"))
font_italic = FontManager(("https://github.com/gitMIGmig/fonts/blob/master/AdihausDIN-Bold.ttf?raw=true"))
font_quad = FontManager(("https://github.com/joroKr21/photoroom/blob/master/fonts/ARCENA.ttf?raw=true"))
font_bold = FontManager(("https://github.com/google/fonts/blob/main/apache/maidenorange/MaidenOrange-Regular.ttf?raw=true"))
font_annot = FontManager(("https://github.com/google/fonts/blob/main/apache/rancho/Rancho-Regular.ttf?raw=true"))
font_number = FontManager(("https://github.com/google/fonts/blob/main/ofl/lato/Lato-Regular.ttf?raw=true"))
font_fig = FontManager(("https://github.com/artpi/LearnMinder/blob/master/android/app/src/main/assets/fonts/Blogger%20Sans-Medium.ttf?raw=true"))

# %%
TITLE1="LA LIGA TOP SIX: 2021/22"
TITLE2="xG Created vs xG Conceded for Every Game"
TITLE3="All LaLiga games in the 2021/22 season"
plt.text(
    .5, 8.3, f"\n{TITLE1}\n{TITLE2}", size=90,
    color="#000000",
    fontproperties=font_bold.prop,
    ha="left"
)   
plt.text(
    .5,7.7 , f"\n{TITLE3}\n", size=55,
    color="#000000",
    fontproperties=font_bold.prop,
    ha="left"
)   
plt.axis('off')

ax = plt.axes([0,0,3,3], frameon=True)  # Change the numbers in this array to position your image [left, bottom, width, height])
image = plt.imread(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\Atleti.png')
ax.imshow(image)
ax.axis('off')

ax = plt.axes([0,3, 3,3], frameon=True)  # Change the numbers in this array to position your image [left, bottom, width, height])
image1 = plt.imread(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\RMA.png')
ax.imshow(image1)
ax.axis('off')

ax = plt.axes([2.5,3, 3,3], frameon=True)  # Change the numbers in this array to position your image [left, bottom, width, height])
image2 = plt.imread(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\Sevilla.png')
ax.imshow(image2)
ax.axis('off')

ax = plt.axes([2.5,0, 3,3], frameon=True)  # Change the numbers in this array to position your image [left, bottom, width, height])
image3 = plt.imread(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\Villa.png')
ax.imshow(image3)
ax.axis('off')

ax = plt.axes([5,0,3,3], frameon=True)  # Change the numbers in this array to position your image [left, bottom, width, height])
image4 = plt.imread(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\Barca.png')
ax.imshow(image4)
ax.axis('off')

ax = plt.axes([5,3,3,3], frameon=True)  # Change the numbers in this array to position your image [left, bottom, width, height])
image5 = plt.imread(r'C:\Users\Sreeram Krishnaswamy\Desktop\Analytics\Betis.png')
ax.imshow(image5)
ax.axis('off')

ax = plt.axes([6.6,6.2, 1, 1], frameon=True)  # Change the numbers in this array to position your image [left, bottom, width, height])
image6 = plt.imread(r'C:\Users\Sreeram Krishnaswamy\Desktop\Wallpapers\liga.png')
ax.imshow(image6)
ax.axis('off')

CREDIT="Data:FBRef. Made by Sreeram | @sreeram14"
plt.text(
    -7000,5700, f"\n{CREDIT}\n", size=50,
    color="#000000",
    fontproperties=font_italic.prop,
    ha="left"
)   
plt.axis('off')
# Out:
# (-0.5, 1161.5, 376.5, -0.5)

# %%
font_cred = FontManager(("https://github.com/gitMIGmig/fonts/blob/master/AdihausDIN-Bold.ttf?raw=true"))
